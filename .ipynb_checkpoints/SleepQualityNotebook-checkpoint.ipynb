# %% [markdown]
# # Sleep Optimization Using Fuzzy Logic
#
# Sleep quality is essential for overall health and well-being, affecting everything from physical performance and mental clarity to mood and immune function. Traditional sleep optimization methods often rely on fixed guidelines, such as the recommended 7-9 hours of sleep per night, but these may not address individual needs, lifestyle factors, or daily variations in energy requirements.
#
# In this notebook, we leverage fuzzy logic to develop a flexible and personalized approach to sleep optimization. Fuzzy logic allows us to handle the uncertainties and nuances associated with human sleep needs. By using this system, users can input factors such as stress level, physical activity, and current sleep quality, receiving personalized suggestions for optimal sleep duration and environment settings.

# %% [markdown]
# # Sleep quality controller
#
# The Sleep Quality Controller assesses your overall sleep quality based on various personal factors, including stress levels, physical activity, and recent sleep patterns. Using fuzzy logic, this controller interprets subjective inputs to gauge how well you are sleeping, providing a nuanced assessment that reflects your current lifestyle and needs.
#
# With this tool, you can better understand the quality of your sleep and identify areas that might need improvement, helping you make informed decisions to enhance your rest and well-being.

# %%
import numpy as np
import skfuzzy as fuzz
import scipy
import networkx
from skfuzzy import control as ctrl

# Defining the Antecedents for each input factor
rhythm = ctrl.Antecedent(np.arange(0, 11, 1), 'rhythm')
stress = ctrl.Antecedent(np.arange(0, 11, 1), 'stress')
duration = ctrl.Antecedent(np.arange(0, 11, 1), 'duration')
activity = ctrl.Antecedent(np.arange(0, 11, 1), 'activity')
food = ctrl.Antecedent(np.arange(0, 11, 1), 'food')
nose_breathing = ctrl.Antecedent(np.arange(0, 11, 1), 'nose_breathing')
environment = ctrl.Antecedent(np.arange(0, 11, 1), 'environment')

# Defining the Consequent for sleep quality
sleep_quality = ctrl.Consequent(np.arange(0, 11, 1), 'sleep_quality')

# Auto-populate membership functions for antecedents (5 levels: poor, mediocre, average, decent, good)
rhythm.automf(5)
stress.automf(5)
duration.automf(5)
activity.automf(5)
food.automf(5)
nose_breathing.automf(5)
environment.automf(5)

# Custom membership functions for the consequent (sleep quality) with 5 levels
sleep_quality['poor'] = fuzz.trimf(sleep_quality.universe, [0, 0, 2.5])
sleep_quality['mediocre'] = fuzz.trimf(sleep_quality.universe, [0, 2.5, 5])
sleep_quality['average'] = fuzz.trimf(sleep_quality.universe, [2.5, 5, 7.5])
sleep_quality['decent'] = fuzz.trimf(sleep_quality.universe, [5, 7.5, 10])
sleep_quality['good'] = fuzz.trimf(sleep_quality.universe, [7.5, 10, 10])

# %%
rhythm['average'].view()
# Out:
# /Users/mohammadeglil/scikit-fuzzy/skfuzzy/control/term.py:72: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
sleep_quality['average'].view()

# %% [markdown]
# # Fuzzy Rules
#
# To make our fuzzy inputs meaningful, we define relationships between input factors (Rhythm, Stress, Duration, Activity, Food, Nose Breathing, and Environment) and the output variable, Sleep Quality. For our sleep quality model, consider these sample fuzzy rules:
#
# - **If stress is high OR environment is poor, then sleep quality will be low.**
# - **If duration is average and activity is decent, then sleep quality will be medium.**
# - **If rhythm is good AND nose breathing is good, then sleep quality will be high.**
#
# These rules reflect common-sense understandings of sleep quality influences, but they are inherently imprecise, with terms like "high," "average," or "good" representing subjective assessments. Mapping these nuanced, "fuzzy" relationships into a clear sleep quality assessment is complex. This is where fuzzy logic shines, providing a framework to translate these rules into actionable insights about sleep quality.

# %%
# Rules focusing on poor sleep quality
rule1 = ctrl.Rule(stress['poor'] | environment['poor'] | rhythm['poor'], sleep_quality['poor'])
rule2 = ctrl.Rule(duration['poor'] & activity['poor'], sleep_quality['poor'])
rule3 = ctrl.Rule(food['poor'] & nose_breathing['poor'], sleep_quality['poor'])
rule4 = ctrl.Rule(stress['poor'] & environment['mediocre'], sleep_quality['poor'])

# Rules with mediocre sleep quality
rule5 = ctrl.Rule(stress['mediocre'] | environment['mediocre'] | duration['mediocre'], sleep_quality['mediocre'])
rule6 = ctrl.Rule(activity['mediocre'] & food['mediocre'], sleep_quality['mediocre'])
rule7 = ctrl.Rule(nose_breathing['mediocre'] & rhythm['mediocre'], sleep_quality['mediocre'])
rule8 = ctrl.Rule((duration['mediocre'] & activity['poor']) | (environment['mediocre'] & food['poor']), sleep_quality['mediocre'])

# Rules for average sleep quality
rule9 = ctrl.Rule(stress['average'] & activity['average'], sleep_quality['average'])
rule10 = ctrl.Rule(duration['average'] & rhythm['average'], sleep_quality['average'])
rule11 = ctrl.Rule(environment['average'] & food['average'], sleep_quality['average'])
rule12 = ctrl.Rule(rhythm['average'] & nose_breathing['average'], sleep_quality['average'])
rule13 = ctrl.Rule(duration['average'] & (food['decent'] | activity['decent']), sleep_quality['average'])

# Rules for decent sleep quality
rule14 = ctrl.Rule((stress['decent'] | duration['decent']) & (environment['average'] | rhythm['decent']), sleep_quality['decent'])
rule15 = ctrl.Rule(food['decent'] & activity['decent'], sleep_quality['decent'])
rule16 = ctrl.Rule(nose_breathing['decent'] & environment['decent'], sleep_quality['decent'])
rule17 = ctrl.Rule(duration['decent'] & rhythm['good'], sleep_quality['decent'])

# Rules focusing on good sleep quality
rule18 = ctrl.Rule(rhythm['good'] & duration['good'] & activity['good'], sleep_quality['good'])
rule19 = ctrl.Rule(food['good'] & nose_breathing['good'] & environment['good'], sleep_quality['good'])
rule20 = ctrl.Rule(stress['decent'] & rhythm['good'] & activity['good'], sleep_quality['good'])
rule21 = ctrl.Rule(duration['good'] & environment['good'] & nose_breathing['good'], sleep_quality['good'])

# Additional rules to cover beneficial combinations
rule22 = ctrl.Rule(stress['decent'] & food['good'], sleep_quality['good'])
rule23 = ctrl.Rule(activity['good'] & environment['good'], sleep_quality['good'])
rule24 = ctrl.Rule(stress['decent'] | duration['good'] & activity['good'], sleep_quality['good'])
rule25 = ctrl.Rule(nose_breathing['good'] & rhythm['good'], sleep_quality['good'])

# Visualization of one of the rules as an example
rule1.view()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %% [markdown]
# # Control System Creation
#
# Now that we have our rules defined, we can simply create a control system via:

# %%
sleep_quality_ctrl = ctrl.ControlSystem([
    rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9, rule10,
    rule11, rule12, rule13, rule14, rule15, rule16, rule17, rule18, rule19, rule20,
    rule21, rule22, rule23, rule24, rule25
])

# %%
sleep_quality_simulation = ctrl.ControlSystemSimulation(sleep_quality_ctrl)

# %%
# Pass inputs to the ControlSystemSimulation using Antecedent labels
# Note: if you like passing many inputs all at once, use .inputs(dict_of_data)

# Setting input values for each Antecedent in the sleep quality system
sleep_quality_simulation.input['rhythm'] = 6.5
sleep_quality_simulation.input['stress'] = 8.0
sleep_quality_simulation.input['duration'] = 7.0
sleep_quality_simulation.input['activity'] = 5.5
sleep_quality_simulation.input['food'] = 6.0
sleep_quality_simulation.input['nose_breathing'] = 7.5
sleep_quality_simulation.input['environment'] = 8.0

# Compute the sleep quality based on the inputs
sleep_quality_simulation.compute()

# Once computed, we can view the result as well as visualize it.
print("Predicted Sleep Quality:", sleep_quality_simulation.output['sleep_quality'])
sleep_quality.view(sim=sleep_quality_simulation)
# Out:
# Predicted Sleep Quality: 7.2716894977168955
# /Users/mohammadeglil/scikit-fuzzy/skfuzzy/control/fuzzyvariable.py:125: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# # Defuzzification
#
# Fuzzy logic calculations are excellent tools, but to use them the fuzzy result must be converted back into a single number. This is known as defuzzification.
# There are several possible methods for defuzzification, exposed via skfuzzy.defuzz.

# %%
import matplotlib.pyplot as plt

# Generate trapezoidal membership function on range [0, 1]
x = np.arange(0, 5.05, 0.1)
mfx = fuzz.trapmf(x, [2, 2.5, 3, 4.5])

# Defuzzify this membership function five ways
defuzz_centroid = fuzz.defuzz(x, mfx, 'centroid')  # Same as skfuzzy.centroid
defuzz_bisector = fuzz.defuzz(x, mfx, 'bisector')
defuzz_mom = fuzz.defuzz(x, mfx, 'mom')
defuzz_som = fuzz.defuzz(x, mfx, 'som')
defuzz_lom = fuzz.defuzz(x, mfx, 'lom')

# Collect info for vertical lines
labels = ['centroid', 'bisector', 'mean of maximum', 'min of maximum',
          'max of maximum']
xvals = [defuzz_centroid,
         defuzz_bisector,
         defuzz_mom,
         defuzz_som,
         defuzz_lom]
colors = ['r', 'b', 'g', 'c', 'm']
ymax = [fuzz.interp_membership(x, mfx, i) for i in xvals]

# Display and compare defuzzification results against membership function
plt.figure(figsize=(8, 5))

plt.plot(x, mfx, 'k')
for xv, y, label, color in zip(xvals, ymax, labels, colors):
    plt.vlines(xv, 0, y, label=label, color=color)
plt.ylabel('Fuzzy membership')
plt.xlabel('Universe variable (arb)')
plt.ylim(-0.1, 1.1)
plt.legend(loc=2)

plt.show()
